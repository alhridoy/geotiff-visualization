# %%
import rasterio
import numpy as np
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
 dataset = rasterio.open('NO2_Benin_city_April_2019.tif')

# %%
import rasterio
from matplotlib import pyplot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,6))
src = rasterio.open("NO2_Benin_city_April_2019.tif")



plot=pyplot.imshow(src.read(1), cmap='Reds',norm=matplotlib.colors.LogNorm(vmin=0.000047, vmax=0.000065))

plt.title('Tropospheric No2 concentration(mole) April 2020 Benin city',fontsize=9)


cbar = fig.colorbar(plot)
cbar.ax.get_yaxis().labelpad = 15
cbar.ax.set_ylabel('Tropospheric No2 concentration(mole)', rotation=270, fontsize=11)

# ax.set_axis_off()


plt.show()
plt.tight_layout()
# Get numerical values of yticks, assuming a linear range between vmin and vmax:

# %%
import rasterio
from matplotlib import pyplot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,6))
src = rasterio.open("NO2_Benin_city_April_2019.tif")



plot=pyplot.imshow(src.read(1), cmap='Reds')




cbar = fig.colorbar(plot)
cbar.ax.get_yaxis().labelpad = 15
cbar.ax.set_ylabel('Tropospheric No2 concentration(mole)', rotation=270, fontsize=11)

# ax.set_axis_off()


plt.show()
plt.tight_layout()
# Get numerical values of yticks, assuming a linear range between vmin and vmax:
plot

# %%
import rasterio
from matplotlib import pyplot
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(6,6))
src = rasterio.open("NO2_aba_April_2019.tif")


plt.title('Tropospheric No2 concentration(mole) April 2020 aba city',fontsize=9)
plot=pyplot.imshow(src.read(1), cmap='Reds',)




cbar = fig.colorbar(plot)
cbar.ax.get_yaxis().labelpad = 15
cbar.ax.set_ylabel('No2', rotation=270, fontsize=15)

# ax.set_axis_off()


plt.show()
plt.tight_layout()
# Get numerical values of yticks, assuming a linear range between vmin and vmax:
plot
